# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('./breast-cancer (1).csv')
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# 2          0.10960           0.15990         0.19740              0.12790
# 3          0.14250           0.28390         0.24140              0.10520
# 4          0.10030           0.13280         0.19800              0.10430
# 5          0.12780           0.17000         0.15780              0.08089
# 6          0.09463           0.10900         0.11270              0.07400
# 7          0.11890           0.16450         0.09366              0.05985
# 8          0.12730           0.19320         0.18590              0.09353
# 9          0.11860           0.23960         0.22730              0.08543
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
# 5  ...          23.75           103.40       741.6            0.1791
# 6  ...          27.66           153.20      1606.0            0.1442
# 7  ...          28.14           110.60       897.0            0.1654
# 8  ...          30.73           106.20       739.3            0.1703
# 9  ...          40.68            97.65       711.4            0.1853
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
# 5             0.5249           0.5355                0.1741          0.3985
# 6             0.2576           0.3784                0.1932          0.3063
# 7             0.3682           0.2678                0.1556          0.3196
# 8             0.5401           0.5390                0.2060          0.4378
# 9             1.0580           1.1050                0.2210          0.4366
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
# 5                  0.12440          NaN
# 6                  0.08368          NaN
# 7                  0.11510          NaN
# 8                  0.10720          NaN
# 9                  0.20750          NaN
#
# [10 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df = df.drop(['id' , 'Unnamed: 32'],axis = 1)

# %%
df['diagnosis'] = df['diagnosis'].map({'M':0 , 'B':1}).astype(int)

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[: , 1:]
y = df.iloc[: , 0]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
len(X_train) , len(y_train)
# Out:
# (381, 381)

# %%
len(X_test) , len(y_test)
# Out:
# (188, 188)

# %% [markdown]
# ## ANN

# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Activation
from tensorflow.keras.activations import relu,sigmoid,softmax

# %% [markdown]
# ### Developing Architecture

# %%
X_train.shape
# Out:
# (381, 30)

# %%
model = Sequential()

# hidden layer 1
model.add(Dense(units=256,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
# hidden layer 2
model.add(Dense(units = 126 , activation='relu',kernel_initializer='he_uniform'))
# hidden layer 3
model.add(Dense(units = 63 , activation='relu',kernel_initializer='he_uniform'))
# hidden layer 4
model.add(Dense(units = 32 , activation='relu',kernel_initializer='he_uniform'))
#  hidden layer 5
model.add(Dense(units = 16 , activation='relu',kernel_initializer='he_uniform'))
# hidden layer 6
model.add(Dense(units = 8 , activation='relu',kernel_initializer='he_uniform'))
# hidden layer 7
model.add(Dense(units = 4 , activation='relu',kernel_initializer='he_uniform'))
# hidden layer 8
model.add(Dense(units = 2 , activation='relu',kernel_initializer='he_uniform'))
#  hidden layer 9
model.add(Dense(units = 1 , activation='sigmoid',kernel_initializer='glorot_uniform'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 256)               7936
#
#  dense_12 (Dense)            (None, 126)               32382
#
#  dense_13 (Dense)            (None, 63)                8001
#
#  dense_14 (Dense)            (None, 32)                2048
#
#  dense_15 (Dense)            (None, 16)                528
#
#  dense_16 (Dense)            (None, 8)                 136
#
#  dense_17 (Dense)            (None, 4)                 36
#
#  dense_18 (Dense)            (None, 2)                 10
#
#  dense_19 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 51,080
# Trainable params: 51,080
# Non-trainable params: 0
# _________________________________________________________________

# %% [raw]
# ##  parameters information
# model = Sequential()
#
# # hidden layer 1
# model.add(Dense(units=4,activation='relu',kernel_initializer='he_uniform',input_dim = 2))
# # hidden layer 2
# model.add(Dense(units = 1 , activation='sigmoid',kernel_initializer='glorot_uniform'))

# %% [raw]
# # model.summary()

# %%
model.compile(loss = 'binary_crossentropy' , optimizer = 'adam' , metrics=['accuracy'])

# %%
tf.config.run_functions_eagerly(True)
model.fit(X_train,y_train , batch_size=10 , epochs=50)
# Out:
# Epoch 1/50
#  4/39 [==>...........................] - ETA: 0s - loss: 0.6508 - accuracy: 0.6500
# C:\Users\vinay vk\anaconda3\envs\lig\lib\site-packages\tensorflow\python\data\ops\structured_function.py:264: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 39/39 [==============================] - 1s 31ms/step - loss: 0.6646 - accuracy: 0.6194
# Epoch 2/50
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 3/50
# 39/39 [==============================] - 1s 30ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 4/50
# 39/39 [==============================] - 1s 28ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 5/50
# 39/39 [==============================] - 1s 28ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 6/50
# 39/39 [==============================] - 1s 28ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 7/50
# 39/39 [==============================] - 1s 31ms/step - loss: 0.6646 - accuracy: 0.6194
# Epoch 8/50
# 39/39 [==============================] - 1s 30ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 9/50
# 39/39 [==============================] - 1s 27ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 10/50
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 11/50
# 39/39 [==============================] - 1s 33ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 12/50
# 39/39 [==============================] - 1s 36ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 13/50
# 39/39 [==============================] - 1s 27ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 14/50
# 39/39 [==============================] - 1s 30ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 15/50
# 39/39 [==============================] - 1s 33ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 16/50
# 39/39 [==============================] - 1s 27ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 17/50
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 18/50
# 39/39 [==============================] - 1s 27ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 19/50
# 39/39 [==============================] - 1s 36ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 20/50
# 39/39 [==============================] - 1s 31ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 21/50
# 39/39 [==============================] - 1s 28ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 22/50
# 39/39 [==============================] - 1s 32ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 23/50
# 39/39 [==============================] - 2s 47ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 24/50
# 39/39 [==============================] - 1s 38ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 25/50
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 26/50
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 27/50
# 39/39 [==============================] - 2s 47ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 28/50
# 39/39 [==============================] - 2s 42ms/step - loss: 0.6645 - accuracy: 0.6194
# Epoch 29/50
# 39/39 [==============================] - 2s 38ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 30/50
# 39/39 [==============================] - 1s 35ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 31/50
# 39/39 [==============================] - 1s 38ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 32/50
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 33/50
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 34/50
# 39/39 [==============================] - 1s 33ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 35/50
# 39/39 [==============================] - 1s 35ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 36/50
# 39/39 [==============================] - 1s 32ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 37/50
# 39/39 [==============================] - 1s 30ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 38/50
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 39/50
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 40/50
# 39/39 [==============================] - 1s 30ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 41/50
# 39/39 [==============================] - 1s 32ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 42/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 43/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 44/50
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 45/50
# 39/39 [==============================] - 1s 27ms/step - loss: 0.6643 - accuracy: 0.6194
# Epoch 46/50
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 47/50
# 39/39 [==============================] - 1s 28ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 48/50
# 39/39 [==============================] - 1s 29ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 49/50
# 39/39 [==============================] - 1s 31ms/step - loss: 0.6644 - accuracy: 0.6194
# Epoch 50/50
# 39/39 [==============================] - 1s 28ms/step - loss: 0.6644 - accuracy: 0.6194
